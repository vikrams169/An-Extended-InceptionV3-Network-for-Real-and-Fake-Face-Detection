# %% [markdown]
# # Introduction
# This iPython notebook aims at undestanding the network architecture of the model used in Training.ipynb, and further analysing it.

# %%
#Importing all the relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras.models import load_model
from keras.utils import plot_model

# %%
#Summarising the model trained
model_realfake=load_model("model_realfake.h5")
model_realfake.summary()
# Out:
# WARNING:tensorflow:From C:\Users\vikra\anaconda\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         (None, 299, 299, 3)       0
# _________________________________________________________________
# inception_v3 (Model)         multiple                  21802784
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 4, 4, 2048)        0
# _________________________________________________________________
# batch_normalization_189 (Bat (None, 4, 4, 2048)        8192
# _________________________________________________________________
# ...

# %%
#Visualising the model architecture
plot_model(model_realfake,to_file="model_realfake.jpg")
